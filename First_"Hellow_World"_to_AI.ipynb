# %% [markdown]
# <a href="https://colab.research.google.com/github/stevengregori92/Introduce-AI/blob/main/First_%22Hellow_World%22_to_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential([Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')

xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

model.fit(xs, ys, epochs=500)

print(model.predict([10.0]))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 291ms/step - loss: 23.7251
# Epoch 2/500
# 1/1 [==============================] - 0s 9ms/step - loss: 18.9502
# Epoch 3/500
# 1/1 [==============================] - 0s 9ms/step - loss: 15.1876
# Epoch 4/500
# 1/1 [==============================] - 0s 9ms/step - loss: 12.2217
# Epoch 5/500
# 1/1 [==============================] - 0s 9ms/step - loss: 9.8826
# Epoch 6/500
# 1/1 [==============================] - 0s 9ms/step - loss: 8.0369
# Epoch 7/500
# 1/1 [==============================] - 0s 9ms/step - loss: 6.5794
# Epoch 8/500
# 1/1 [==============================] - 0s 10ms/step - loss: 5.4274
# Epoch 9/500
# 1/1 [==============================] - 0s 9ms/step - loss: 4.5159
# Epoch 10/500
# 1/1 [==============================] - 0s 10ms/step - loss: 3.7938
# Epoch 11/500
# 1/1 [==============================] - 0s 8ms/step - loss: 3.2207
# Epoch 12/500
# 1/1 [==============================] - 0s 8ms/step - loss: 2.7649
# ...

# %%
l0 = Dense(units = 1, input_shape = [1])
model = Sequential([l0])
model.compile(optimizer = 'sgd', loss = 'mean_squared_error')

xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

model.fit(xs, ys, epochs=500)

print(model.predict([10.0]))
print('Here is what I learned: {}'.format(l0.get_weights()))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 302ms/step - loss: 2.0611
# Epoch 2/500
# 1/1 [==============================] - 0s 13ms/step - loss: 1.7663
# Epoch 3/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.5313
# Epoch 4/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3436
# Epoch 5/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1930
# Epoch 6/500
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0718
# Epoch 7/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.9736
# Epoch 8/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.8938
# Epoch 9/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.8283
# Epoch 10/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7742
# Epoch 11/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7292
# Epoch 12/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6912
# ...

# %%
l0 = Dense(units = 3, input_shape = [1])
l1 = Dense(units = 3, input_shape = [1])
model = Sequential([l0, l1])
model.compile(optimizer = 'sgd', loss = 'mean_squared_error')

xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

model.fit(xs, ys, epochs=500)

print(model.predict([10.0]))
print('Here is what I learned: {}'.format(l0.get_weights()))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 1s 879ms/step - loss: 16.8303
# Epoch 2/500
# 1/1 [==============================] - 0s 9ms/step - loss: 13.7010
# Epoch 3/500
# 1/1 [==============================] - 0s 10ms/step - loss: 11.3801
# Epoch 4/500
# 1/1 [==============================] - 0s 9ms/step - loss: 9.5201
# Epoch 5/500
# 1/1 [==============================] - 0s 15ms/step - loss: 7.9562
# Epoch 6/500
# 1/1 [==============================] - 0s 10ms/step - loss: 6.6095
# Epoch 7/500
# 1/1 [==============================] - 0s 12ms/step - loss: 5.4436
# Epoch 8/500
# 1/1 [==============================] - 0s 14ms/step - loss: 4.4425
# Epoch 9/500
# 1/1 [==============================] - 0s 8ms/step - loss: 3.5974
# Epoch 10/500
# 1/1 [==============================] - 0s 9ms/step - loss: 2.9002
# Epoch 11/500
# 1/1 [==============================] - 0s 8ms/step - loss: 2.3395
# Epoch 12/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.9001
# ...
